# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\output'

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 36

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"06-04-2023",
                        "Person ID": 164,
                        "Test ID": 518,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")


df.to_csv('06-04-2023_c1_test1.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-27-00_0.tiff: 480x640 3 persons, 2719.3ms
# Speed: 2.0ms preprocess, 2719.3ms inference, 969.8ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-28-00_0.tiff: 480x640 3 persons, 3144.3ms
# Speed: 3.0ms preprocess, 3144.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-29-00_0.tiff: 480x640 3 persons, 3255.4ms
# Speed: 1.0ms preprocess, 3255.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-30-00_0.tiff: 480x640 2 persons, 2909.7ms
# Speed: 2.0ms preprocess, 2909.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-31-00_0.tiff: 480x640 2 persons, 3214.4ms
# Speed: 2.0ms preprocess, 3214.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-32-00_0.tiff: 480x640 2 persons, 3221.7ms
# Speed: 1.0ms preprocess, 3221.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-33-00_0.tiff: 480x640 2 persons, 3034.0ms
# Speed: 1.0ms preprocess, 3034.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-34-00_0.tiff: 480x640 2 persons, 2927.6ms
# Speed: 2.0ms preprocess, 2927.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-35-00_0.tiff: 480x640 3 persons, 2811.5ms
# Speed: 2.0ms preprocess, 2811.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-36-00_0.tiff: 480x640 2 persons, 2857.3ms
# Speed: 1.0ms preprocess, 2857.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-37-01_0.tiff: 480x640 2 persons, 2987.0ms
# Speed: 1.0ms preprocess, 2987.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-38-00_0.tiff: 480x640 2 persons, 2946.2ms
# Speed: 3.0ms preprocess, 2946.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-39-00_0.tiff: 480x640 2 persons, 2960.8ms
# Speed: 2.0ms preprocess, 2960.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-40-00_0.tiff: 480x640 2 persons, 3090.1ms
# Speed: 2.0ms preprocess, 3090.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-41-00_0.tiff: 480x640 2 persons, 3264.1ms
# Speed: 1.0ms preprocess, 3264.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-42-00_0.tiff: 480x640 2 persons, 2911.8ms
# Speed: 2.0ms preprocess, 2911.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-43-01_0.tiff: 480x640 2 persons, 3057.5ms
# Speed: 2.0ms preprocess, 3057.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-44-00_0.tiff: 480x640 2 persons, 3117.2ms
# Speed: 2.0ms preprocess, 3117.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-45-00_0.tiff: 480x640 2 persons, 2847.3ms
# Speed: 2.0ms preprocess, 2847.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-46-00_0.tiff: 480x640 2 persons, 3194.2ms
# Speed: 3.0ms preprocess, 3194.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-47-00_0.tiff: 480x640 2 persons, 3291.9ms
# Speed: 2.0ms preprocess, 3291.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-48-00_0.tiff: 480x640 2 persons, 3062.0ms
# Speed: 1.0ms preprocess, 3062.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-49-00_0.tiff: 480x640 2 persons, 3093.0ms
# Speed: 2.0ms preprocess, 3093.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-50-00_0.tiff: 480x640 2 persons, 3263.8ms
# Speed: 2.0ms preprocess, 3263.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-51-00_0.tiff: 480x640 2 persons, 3209.0ms
# Speed: 2.0ms preprocess, 3209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-52-00_0.tiff: 480x640 2 persons, 2804.3ms
# Speed: 2.0ms preprocess, 2804.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-53-00_0.tiff: 480x640 3 persons, 2728.4ms
# Speed: 2.0ms preprocess, 2728.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-54-00_0.tiff: 480x640 2 persons, 2822.9ms
# Speed: 1.0ms preprocess, 2822.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-55-00_0.tiff: 480x640 2 persons, 2711.7ms
# Speed: 2.0ms preprocess, 2711.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-56-00_0.tiff: 480x640 3 persons, 2896.9ms
# Speed: 2.0ms preprocess, 2896.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-57-00_0.tiff: 480x640 2 persons, 2737.3ms
# Speed: 1.0ms preprocess, 2737.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test1\Record_2023-04-06_09-58-00_0.tiff: 480x640 3 persons, 2726.5ms
# Speed: 2.0ms preprocess, 2726.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\output'

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 36

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"06-04-2023",
                        "Person ID": 67,
                        "Test ID": 518,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")


df.to_csv('06-04-2023_c1_test2.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-32-00_0.tiff: 480x640 2 persons, 2870.3ms
# Speed: 1.0ms preprocess, 2870.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-33-01.tiff: 480x640 4 persons, 3238.7ms
# Speed: 1.3ms preprocess, 3238.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-34-00_0.tiff: 480x640 2 persons, 2882.1ms
# Speed: 1.0ms preprocess, 2882.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-35-00_0.tiff: 480x640 2 persons, 2902.8ms
# Speed: 2.0ms preprocess, 2902.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-36-01_0.tiff: 480x640 2 persons, 2985.0ms
# Speed: 2.0ms preprocess, 2985.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-37-00_0.tiff: 480x640 1 person, 2964.0ms
# Speed: 1.0ms preprocess, 2964.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-38-00_0.tiff: 480x640 2 persons, 2888.1ms
# Speed: 1.0ms preprocess, 2888.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-39-00_0.tiff: 480x640 2 persons, 2876.9ms
# Speed: 2.0ms preprocess, 2876.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-40-00_0.tiff: 480x640 2 persons, 2974.6ms
# Speed: 1.0ms preprocess, 2974.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-41-01_0.tiff: 480x640 1 person, 2946.3ms
# Speed: 2.0ms preprocess, 2946.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-42-01_0.tiff: 480x640 1 person, 2802.4ms
# Speed: 2.0ms preprocess, 2802.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-43-01_0.tiff: 480x640 2 persons, 2701.9ms
# Speed: 1.0ms preprocess, 2701.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-44-00_0.tiff: 480x640 1 person, 2694.9ms
# Speed: 2.0ms preprocess, 2694.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-45-00_0.tiff: 480x640 1 person, 2703.2ms
# Speed: 2.0ms preprocess, 2703.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-46-00_0.tiff: 480x640 1 person, 2689.0ms
# Speed: 2.0ms preprocess, 2689.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-47-00_0.tiff: 480x640 2 persons, 2696.5ms
# Speed: 2.0ms preprocess, 2696.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-48-00_0.tiff: 480x640 1 person, 2709.4ms
# Speed: 1.0ms preprocess, 2709.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-49-00_0.tiff: 480x640 2 persons, 2728.4ms
# Speed: 2.0ms preprocess, 2728.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-50-00_0.tiff: 480x640 1 person, 2682.1ms
# Speed: 2.0ms preprocess, 2682.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-51-00_0.tiff: 480x640 2 persons, 2698.6ms
# Speed: 2.0ms preprocess, 2698.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-52-00_0.tiff: 480x640 1 person, 2690.1ms
# Speed: 2.0ms preprocess, 2690.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-53-00_0.tiff: 480x640 2 persons, 2705.6ms
# Speed: 1.0ms preprocess, 2705.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-54-00_0.tiff: 480x640 1 person, 3046.8ms
# Speed: 1.0ms preprocess, 3046.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-55-00_0.tiff: 480x640 2 persons, 3049.6ms
# Speed: 1.0ms preprocess, 3049.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-56-00_0.tiff: 480x640 1 person, 2793.3ms
# Speed: 2.0ms preprocess, 2793.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-57-00_0.tiff: 480x640 1 person, 2729.8ms
# Speed: 2.0ms preprocess, 2729.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-58-00_0.tiff: 480x640 1 person, 2729.8ms
# Speed: 2.0ms preprocess, 2729.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_12-59-00_0.tiff: 480x640 1 person, 2707.6ms
# Speed: 1.0ms preprocess, 2707.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_13-00-00_0.tiff: 480x640 1 person, 2907.6ms
# Speed: 1.0ms preprocess, 2907.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_13-01-01.tiff: 480x640 2 persons, 2760.7ms
# Speed: 2.0ms preprocess, 2760.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_13-02-00_0.tiff: 480x640 2 persons, 2765.0ms
# Speed: 1.0ms preprocess, 2765.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_13-03-00_0.tiff: 480x640 4 persons, 2868.6ms
# Speed: 2.0ms preprocess, 2868.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_13-04-01.tiff: 480x640 6 persons, 2825.5ms
# Speed: 2.0ms preprocess, 2825.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
# Person 5 is outside the ROI and will be ignored.
# Person 6 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test2\Record_2023-04-06_13-05-00_0.tiff: 480x640 3 persons, 2770.7ms
# Speed: 1.0ms preprocess, 2770.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.

# %% [markdown]
# Test 3 / Camera 1

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test3\output'

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 36

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"06-04-2023",
                        "Person ID": 135,
                        "Test ID": 518,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_E
6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test3\Record_2023-04-06_15-49-00_0.tiff: 480x640 3 persons, 2740.5ms
# Speed: 2.0ms preprocess, 2740.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test3\Record_2023-04-06_15-50-00_0.tiff: 480x640 6 persons, 3193.8ms
# Speed: 2.0ms preprocess, 3193.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
# Person 5 is outside the ROI and will be ignored.
# Person 6 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test3\Record_2023-04-06_15-51-00_0.tiff: 480x640 4 persons, 2697.6ms
# Speed: 1.0ms preprocess, 2697.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera1\test3\Record_2023-04-06_15-52-00_0.tiff: 480x640 4 persons, 3166.1ms
# Speed: 1.0ms preprocess, 3166.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.

# %% [markdown]
# Camera 2 / Test 1

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolo11x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\yolo11'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 37

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.3:
                seat_id = 4
                seat_label = "4"
                person_id = 150  
                test_id = 517    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 142  
                test_id = 513  
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "06-04-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

group_1_df = df[(df['Test ID'] == 517) & (df['Person ID'] == 150)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('06-04-2023_c2_test1_150_517.csv', index=False)

group_2_df = df[(df['Test ID'] == 513) & (df['Person ID'] == 142)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('06-04-2023_c2_test1_142_513.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-27-00.tiff: 480x640 3 persons, 1188.7ms
# Speed: 2.0ms preprocess, 1188.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-28-00.tiff: 480x640 4 persons, 1141.4ms
# Speed: 2.0ms preprocess, 1141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-29-00.tiff: 480x640 4 persons, 1122.9ms
# Speed: 1.0ms preprocess, 1122.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-30-00.tiff: 480x640 3 persons, 1101.9ms
# Speed: 2.0ms preprocess, 1101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-31-00.tiff: 480x640 2 persons, 1047.6ms
# Speed: 1.0ms preprocess, 1047.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-32-00.tiff: 480x640 3 persons, 1040.4ms
# Speed: 2.0ms preprocess, 1040.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-33-00.tiff: 480x640 2 persons, 1072.1ms
# Speed: 1.0ms preprocess, 1072.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-34-00.tiff: 480x640 2 persons, 1119.8ms
# Speed: 1.0ms preprocess, 1119.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-35-00.tiff: 480x640 2 persons, 1053.6ms
# Speed: 1.0ms preprocess, 1053.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-36-00.tiff: 480x640 2 persons, 1058.3ms
# Speed: 2.0ms preprocess, 1058.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-37-01.tiff: 480x640 2 persons, 1065.1ms
# Speed: 1.0ms preprocess, 1065.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-38-00.tiff: 480x640 3 persons, 1062.3ms
# Speed: 1.0ms preprocess, 1062.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-39-00.tiff: 480x640 3 persons, 1113.8ms
# Speed: 2.0ms preprocess, 1113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-40-00.tiff: 480x640 2 persons, 1079.5ms
# Speed: 1.0ms preprocess, 1079.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-41-00.tiff: 480x640 3 persons, 1033.0ms
# Speed: 1.0ms preprocess, 1033.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-42-00.tiff: 480x640 3 persons, 1078.4ms
# Speed: 2.0ms preprocess, 1078.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-43-01.tiff: 480x640 2 persons, 1075.0ms
# Speed: 2.0ms preprocess, 1075.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-44-00.tiff: 480x640 3 persons, 1062.1ms
# Speed: 1.0ms preprocess, 1062.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-45-00.tiff: 480x640 3 persons, 1145.6ms
# Speed: 2.0ms preprocess, 1145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-46-00.tiff: 480x640 2 persons, 1152.4ms
# Speed: 2.0ms preprocess, 1152.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-47-00.tiff: 480x640 1 person, 1086.9ms
# Speed: 1.0ms preprocess, 1086.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-48-00.tiff: 480x640 2 persons, 1063.2ms
# Speed: 2.0ms preprocess, 1063.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-49-00.tiff: 480x640 3 persons, 1057.7ms
# Speed: 1.0ms preprocess, 1057.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-50-00.tiff: 480x640 3 persons, 1088.1ms
# Speed: 2.0ms preprocess, 1088.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-51-00.tiff: 480x640 3 persons, 1078.3ms
# Speed: 1.0ms preprocess, 1078.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-52-00.tiff: 480x640 2 persons, 1093.2ms
# Speed: 1.0ms preprocess, 1093.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-53-00.tiff: 480x640 3 persons, 1098.6ms
# Speed: 1.0ms preprocess, 1098.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-54-00.tiff: 480x640 3 persons, 1125.7ms
# Speed: 1.0ms preprocess, 1125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-55-00.tiff: 480x640 2 persons, 1048.4ms
# Speed: 1.0ms preprocess, 1048.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test1\Record_2023-04-06_09-56-00.tiff: 480x640 1 person, 1135.6ms
# Speed: 2.0ms preprocess, 1135.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.

# %% [markdown]
# Test 2

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\output'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 37

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 164  
                test_id = 517    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 165  
                test_id = 513  
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "06-04-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

group_1_df = df[(df['Test ID'] == 517) & (df['Person ID'] == 150)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('06-04-2023_c2_test2_150_517.csv', index=False)

group_2_df = df[(df['Test ID'] == 513) & (df['Person ID'] == 142)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('06-04-2023_c2_test2_142_513.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-32-00.tiff: 480x640 7 persons, 3026.0ms
# Speed: 1.0ms preprocess, 3026.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 4 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is within seat 2 and will be processed.
# Person 6 is not predominantly in either ROI and will be ignored.
# Person 7 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-33-00.tiff: 480x640 4 persons, 2686.6ms
# Speed: 1.0ms preprocess, 2686.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-34-00.tiff: 480x640 5 persons, 2784.4ms
# Speed: 1.0ms preprocess, 2784.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-35-00.tiff: 480x640 5 persons, 2799.4ms
# Speed: 2.0ms preprocess, 2799.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-36-01.tiff: 480x640 3 persons, 2705.1ms
# Speed: 1.0ms preprocess, 2705.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-37-00.tiff: 480x640 2 persons, 2712.5ms
# Speed: 1.0ms preprocess, 2712.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-38-00.tiff: 480x640 6 persons, 2850.4ms
# Speed: 2.0ms preprocess, 2850.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
# Person 6 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-39-00.tiff: 480x640 4 persons, 2645.8ms
# Speed: 1.0ms preprocess, 2645.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-40-00.tiff: 480x640 4 persons, 2658.8ms
# Speed: 2.0ms preprocess, 2658.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-41-01.tiff: 480x640 3 persons, 2612.6ms
# Speed: 2.0ms preprocess, 2612.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-42-01.tiff: 480x640 3 persons, 2568.3ms
# Speed: 1.0ms preprocess, 2568.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-43-01.tiff: 480x640 2 persons, 2593.9ms
# Speed: 2.0ms preprocess, 2593.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-44-00.tiff: 480x640 3 persons, 2577.1ms
# Speed: 2.0ms preprocess, 2577.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-45-00.tiff: 480x640 2 persons, 2558.6ms
# Speed: 2.0ms preprocess, 2558.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-46-00.tiff: 480x640 5 persons, 2615.6ms
# Speed: 2.0ms preprocess, 2615.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-47-00.tiff: 480x640 2 persons, 2559.1ms
# Speed: 2.0ms preprocess, 2559.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-48-00.tiff: 480x640 6 persons, 2556.6ms
# Speed: 1.0ms preprocess, 2556.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
# Person 6 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-49-00.tiff: 480x640 4 persons, 2545.6ms
# Speed: 2.0ms preprocess, 2545.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-50-00.tiff: 480x640 3 persons, 2544.1ms
# Speed: 2.0ms preprocess, 2544.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-51-00.tiff: 480x640 2 persons, 2543.6ms
# Speed: 2.0ms preprocess, 2543.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-52-00.tiff: 480x640 2 persons, 2546.6ms
# Speed: 1.0ms preprocess, 2546.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-53-00.tiff: 480x640 3 persons, 2553.6ms
# Speed: 1.0ms preprocess, 2553.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-54-00.tiff: 480x640 3 persons, 2568.1ms
# Speed: 1.0ms preprocess, 2568.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-55-00.tiff: 480x640 3 persons, 2553.5ms
# Speed: 1.0ms preprocess, 2553.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-56-00.tiff: 480x640 2 persons, 2607.5ms
# Speed: 0.9ms preprocess, 2607.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-57-00.tiff: 480x640 3 persons, 3058.4ms
# Speed: 1.0ms preprocess, 3058.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-58-00.tiff: 480x640 3 persons, 2961.0ms
# Speed: 2.0ms preprocess, 2961.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_12-59-00.tiff: 480x640 2 persons, 2843.8ms
# Speed: 2.0ms preprocess, 2843.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_13-00-00.tiff: 480x640 3 persons, 2778.1ms
# Speed: 1.0ms preprocess, 2778.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_13-01-00.tiff: 480x640 3 persons, 2729.5ms
# Speed: 2.0ms preprocess, 2729.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_13-02-00.tiff: 480x640 3 persons, 2753.2ms
# Speed: 1.0ms preprocess, 2753.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test2\Record_2023-04-06_13-03-00.tiff: 480x640 2 persons, 2760.6ms
# Speed: 1.0ms preprocess, 2760.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolo11x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test3\yolo11'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 35.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.4:
                seat_id = 4
                seat_label = "4"
                person_id = 142  
                test_id = 517    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 163  
                test_id = 505  
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "06-04-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

group_1_df = df[(df['Test ID'] == 517) & (df['Person ID'] == 142)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('06-04-2023_c2_test3_142_517.csv', index=False)

group_2_df = df[(df['Test ID'] == 505) & (df['Person ID'] == 163)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('06-04-2023_c2_test3_163_505.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-06\06_04_2023_camera2\test3\Record_2023-04-06_15