# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\yolov8'

# Calibration parameters taken from the Pixconnect Software
min_temp = 26.5 
max_temp = 33

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"12-04-2023",
                        "Person ID": 145,
                        "Test ID": 620,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")


df.to_csv('12-04-2023_c1_test1_145_620.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-23-00.tiff: 480x640 4 persons, 1018.4ms
# Speed: 0.0ms preprocess, 1018.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-24-00.tiff: 480x640 2 persons, 886.0ms
# Speed: 0.0ms preprocess, 886.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-25-00.tiff: 480x640 2 persons, 813.8ms
# Speed: 0.0ms preprocess, 813.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-26-01.tiff: 480x640 2 persons, 765.3ms
# Speed: 8.0ms preprocess, 765.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-27-01.tiff: 480x640 2 persons, 824.3ms
# Speed: 0.0ms preprocess, 824.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-28-01.tiff: 480x640 2 persons, 800.1ms
# Speed: 2.0ms preprocess, 800.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-29-01.tiff: 480x640 2 persons, 837.5ms
# Speed: 0.0ms preprocess, 837.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-30-01_0.tiff: 480x640 2 persons, 877.9ms
# Speed: 0.0ms preprocess, 877.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-31-00.tiff: 480x640 2 persons, 872.5ms
# Speed: 0.0ms preprocess, 872.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-32-00.tiff: 480x640 2 persons, 862.1ms
# Speed: 0.0ms preprocess, 862.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-33-00.tiff: 480x640 2 persons, 868.8ms
# Speed: 0.0ms preprocess, 868.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-34-01.tiff: 480x640 2 persons, 868.9ms
# Speed: 0.0ms preprocess, 868.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-35-00.tiff: 480x640 2 persons, 868.9ms
# Speed: 0.0ms preprocess, 868.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-36-00.tiff: 480x640 2 persons, 878.2ms
# Speed: 0.0ms preprocess, 878.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-37-00.tiff: 480x640 2 persons, 876.6ms
# Speed: 0.0ms preprocess, 876.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-38-00.tiff: 480x640 2 persons, 857.6ms
# Speed: 8.0ms preprocess, 857.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-39-01.tiff: 480x640 2 persons, 883.2ms
# Speed: 0.0ms preprocess, 883.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-40-01.tiff: 480x640 3 persons, 871.6ms
# Speed: 0.0ms preprocess, 871.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-41-00.tiff: 480x640 2 persons, 868.4ms
# Speed: 0.0ms preprocess, 868.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-42-01.tiff: 480x640 2 persons, 871.6ms
# Speed: 0.0ms preprocess, 871.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-43-01.tiff: 480x640 2 persons, 871.3ms
# Speed: 0.0ms preprocess, 871.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-44-01.tiff: 480x640 2 persons, 865.6ms
# Speed: 0.0ms preprocess, 865.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-45-00.tiff: 480x640 2 persons, 864.3ms
# Speed: 1.5ms preprocess, 864.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-46-00.tiff: 480x640 3 persons, 897.6ms
# Speed: 3.0ms preprocess, 897.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-47-00.tiff: 480x640 2 persons, 863.5ms
# Speed: 1.0ms preprocess, 863.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-48-00.tiff: 480x640 2 persons, 894.6ms
# Speed: 8.0ms preprocess, 894.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-49-00.tiff: 480x640 2 persons, 932.0ms
# Speed: 0.0ms preprocess, 932.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-50-01.tiff: 480x640 2 persons, 900.5ms
# Speed: 0.0ms preprocess, 900.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-51-00.tiff: 480x640 2 persons, 858.8ms
# Speed: 8.0ms preprocess, 858.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-52-00.tiff: 480x640 2 persons, 850.7ms
# Speed: 0.0ms preprocess, 850.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-53-01.tiff: 480x640 2 persons, 865.6ms
# Speed: 0.0ms preprocess, 865.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-54-00.tiff: 480x640 2 persons, 878.2ms
# Speed: 0.0ms preprocess, 878.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-55-01.tiff: 480x640 2 persons, 869.0ms
# Speed: 0.0ms preprocess, 869.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-56-00.tiff: 480x640 3 persons, 873.9ms
# Speed: 1.0ms preprocess, 873.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test1\Record_2023-04-12_09-57-00.tiff: 480x640 2 persons, 865.9ms
# Speed: 0.0ms preprocess, 865.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.

# %% [markdown]
# Test 2

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\yolov8'

# Calibration parameters taken from the Pixconnect Software
min_temp = 26.5 
max_temp = 33.2
# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"12-04-2023",
                        "Person ID": 122,
                        "Test ID": 620,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")


df.to_csv('12-04-2023_c1_test2_122_620.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-21-00.tiff: 480x640 2 persons, 921.6ms
# Speed: 0.0ms preprocess, 921.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-22-00.tiff: 480x640 3 persons, 907.4ms
# Speed: 0.0ms preprocess, 907.4ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-23-01.tiff: 480x640 2 persons, 912.2ms
# Speed: 8.0ms preprocess, 912.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-24-00.tiff: 480x640 2 persons, 906.5ms
# Speed: 0.0ms preprocess, 906.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-25-01.tiff: 480x640 2 persons, 908.4ms
# Speed: 0.0ms preprocess, 908.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-26-01.tiff: 480x640 2 persons, 915.5ms
# Speed: 0.0ms preprocess, 915.5ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-27-00.tiff: 480x640 3 persons, 882.8ms
# Speed: 0.0ms preprocess, 882.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-28-00.tiff: 480x640 3 persons, 793.7ms
# Speed: 0.0ms preprocess, 793.7ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-29-00.tiff: 480x640 2 persons, 789.3ms
# Speed: 0.0ms preprocess, 789.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-30-00.tiff: 480x640 3 persons, 807.4ms
# Speed: 0.0ms preprocess, 807.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-31-00.tiff: 480x640 2 persons, 896.7ms
# Speed: 0.0ms preprocess, 896.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-32-00.tiff: 480x640 3 persons, 879.6ms
# Speed: 0.0ms preprocess, 879.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-33-01.tiff: 480x640 3 persons, 877.9ms
# Speed: 5.0ms preprocess, 877.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-34-00.tiff: 480x640 2 persons, 886.2ms
# Speed: 0.0ms preprocess, 886.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-35-00.tiff: 480x640 2 persons, 882.2ms
# Speed: 0.0ms preprocess, 882.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-36-01.tiff: 480x640 2 persons, 883.5ms
# Speed: 8.0ms preprocess, 883.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-37-00_0.tiff: 480x640 4 persons, 882.0ms
# Speed: 0.0ms preprocess, 882.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-38-01.tiff: 480x640 2 persons, 917.4ms
# Speed: 0.0ms preprocess, 917.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-39-01.tiff: 480x640 3 persons, 931.1ms
# Speed: 0.0ms preprocess, 931.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-40-01.tiff: 480x640 3 persons, 895.6ms
# Speed: 0.0ms preprocess, 895.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-41-00.tiff: 480x640 4 persons, 897.5ms
# Speed: 0.0ms preprocess, 897.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-42-00.tiff: 480x640 2 persons, 909.1ms
# Speed: 8.0ms preprocess, 909.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-43-00.tiff: 480x640 3 persons, 926.4ms
# Speed: 0.0ms preprocess, 926.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-44-00.tiff: 480x640 3 persons, 891.1ms
# Speed: 0.0ms preprocess, 891.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-45-01.tiff: 480x640 2 persons, 885.4ms
# Speed: 2.0ms preprocess, 885.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-46-01.tiff: 480x640 4 persons, 890.9ms
# Speed: 8.0ms preprocess, 890.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-47-01.tiff: 480x640 2 persons, 896.2ms
# Speed: 0.0ms preprocess, 896.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-48-00.tiff: 480x640 3 persons, 890.3ms
# Speed: 0.0ms preprocess, 890.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-49-00.tiff: 480x640 3 persons, 879.7ms
# Speed: 0.0ms preprocess, 879.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-50-00.tiff: 480x640 2 persons, 900.1ms
# Speed: 0.0ms preprocess, 900.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-51-00.tiff: 480x640 2 persons, 898.0ms
# Speed: 1.5ms preprocess, 898.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-52-00.tiff: 480x640 3 persons, 880.0ms
# Speed: 0.0ms preprocess, 880.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-53-00.tiff: 480x640 2 persons, 904.9ms
# Speed: 0.0ms preprocess, 904.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-54-00.tiff: 480x640 3 persons, 885.6ms
# Speed: 0.0ms preprocess, 885.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test2\Record_2023-04-12_12-55-01.tiff: 480x640 2 persons, 928.3ms
# Speed: 0.0ms preprocess, 928.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test3\output'

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.5 
max_temp = 29

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is
2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test3\Record_2023-04-12_15-55-00.tiff: 480x640 3 persons, 935.2ms
# Speed: 1.0ms preprocess, 935.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera1\test3\Record_2023-04-12_15-56-00.tiff: 480x640 4 persons, 881.2ms
# Speed: 2.0ms preprocess, 881.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.

# %% [markdown]
# Camera 2 / Test 1

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 26.5 
max_temp = 36.3

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 250, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (450, 190, 620, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 149  
                test_id = 620    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 169  
                test_id = 620  
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "12-04-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")


group_1_df = df[(df['Test ID'] == 620) & (df['Person ID'] == 149)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('12-04-2023_c2_test1_149_620.csv', index=False)

group_2_df = df[(df['Test ID'] == 620) & (df['Person ID'] == 169)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('12-04-2023_c2_test1_169_620.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\Record_2023-04-12_09-23-00_0.tiff: 480x640 5 persons, 1186.3ms
# Speed: 2.0ms preprocess, 1186.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\Record_2023-04-12_09-24-00_0.tiff: 480x640 3 persons, 1243.6ms
# Speed: 2.0ms preprocess, 1243.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\Record_2023-04-12_09-25-01.tiff: 480x640 6 persons, 1124.0ms
# Speed: 1.0ms preprocess, 1124.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
# Person 6 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\Record_2023-04-12_09-26-00.tiff: 480x640 3 persons, 1167.0ms
# Speed: 5.0ms preprocess, 1167.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\Record_2023-04-12_09-27-00.tiff: 480x640 6 persons, 1157.9ms
# Speed: 2.0ms preprocess, 1157.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
# Person 6 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test1\Record_2023-04-12_09
# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 26.5 
max_temp = 34

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (80, 190, 250, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (450, 190, 600, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 54 
                test_id = 620    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 145  
                test_id = 620  
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "12-04-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

group_1_df = df[(df['Test ID'] == 620) & (df['Person ID'] == 54)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('12-04-2023_c2_test2_54_620.csv', index=False)

group_2_df = df[(df['Test ID'] == 620) & (df['Person ID'] == 145)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('12-04-2023_c2_test2_145_620.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-23-00.tiff: 480x640 4 persons, 1258.7ms
# Speed: 2.0ms preprocess, 1258.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-24-00_0.tiff: 480x640 4 persons, 1323.2ms
# Speed: 2.0ms preprocess, 1323.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-25-00.tiff: 480x640 5 persons, 1106.8ms
# Speed: 2.0ms preprocess, 1106.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-26-00.tiff: 480x640 4 persons, 1075.5ms
# Speed: 2.0ms preprocess, 1075.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-27-00_0.tiff: 480x640 2 persons, 1074.4ms
# Speed: 1.0ms preprocess, 1074.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-28-00_0.tiff: 480x640 3 persons, 1162.6ms
# Speed: 1.0ms preprocess, 1162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-29-00_0.tiff: 480x640 5 persons, 1053.2ms
# Speed: 1.0ms preprocess, 1053.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-30-00_0.tiff: 480x640 3 persons, 1122.9ms
# Speed: 2.0ms preprocess, 1122.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-31-00_0.tiff: 480x640 2 persons, 1085.2ms
# Speed: 1.0ms preprocess, 1085.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-32-00_0.tiff: 480x640 2 persons, 1174.5ms
# Speed: 1.0ms preprocess, 1174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-33-00.tiff: 480x640 3 persons, 1145.3ms
# Speed: 2.0ms preprocess, 1145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-34-00_0.tiff: 480x640 4 persons, 1183.4ms
# Speed: 2.0ms preprocess, 1183.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-35-00_0.tiff: 480x640 3 persons, 1076.8ms
# Speed: 1.0ms preprocess, 1076.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-36-00.tiff: 480x640 4 persons, 1046.7ms
# Speed: 1.0ms preprocess, 1046.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-37-00.tiff: 480x640 2 persons, 1056.0ms
# Speed: 1.0ms preprocess, 1056.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-38-00.tiff: 480x640 3 persons, 1051.6ms
# Speed: 2.0ms preprocess, 1051.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-39-00.tiff: 480x640 4 persons, 1073.4ms
# Speed: 1.0ms preprocess, 1073.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-40-00.tiff: 480x640 4 persons, 1058.2ms
# Speed: 1.0ms preprocess, 1058.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-41-00_0.tiff: 480x640 2 persons, 1044.6ms
# Speed: 1.0ms preprocess, 1044.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-42-00_0.tiff: 480x640 3 persons, 1046.2ms
# Speed: 2.0ms preprocess, 1046.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-43-00_0.tiff: 480x640 2 persons, 1088.1ms
# Speed: 1.0ms preprocess, 1088.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-44-00_0.tiff: 480x640 3 persons, 1042.7ms
# Speed: 1.0ms preprocess, 1042.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-45-00.tiff: 480x640 3 persons, 1044.3ms
# Speed: 2.0ms preprocess, 1044.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-46-00.tiff: 480x640 2 persons, 1093.8ms
# Speed: 1.0ms preprocess, 1093.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-47-00.tiff: 480x640 4 persons, 1158.9ms
# Speed: 2.0ms preprocess, 1158.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-48-00_0.tiff: 480x640 4 persons, 1079.0ms
# Speed: 2.0ms preprocess, 1079.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-49-00_0.tiff: 480x640 2 persons, 1118.2ms
# Speed: 2.0ms preprocess, 1118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-50-00_0.tiff: 480x640 3 persons, 1069.2ms
# Speed: 1.0ms preprocess, 1069.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-51-00_0.tiff: 480x640 3 persons, 1110.9ms
# Speed: 1.0ms preprocess, 1110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-52-00_0.tiff: 480x640 4 persons, 1047.2ms
# Speed: 2.0ms preprocess, 1047.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-53-00_0.tiff: 480x640 3 persons, 1060.6ms
# Speed: 1.0ms preprocess, 1060.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test2\Record_2023-04-12_12-54-00_0.tiff: 480x640 2 persons, 1071.9ms
# Speed: 1.0ms preprocess, 1071.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test3\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 26.5 
max_temp = 33

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (80, 190, 250, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (450, 190, 600, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 156 
                test_id = 620    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 168  
                test_id = 620  
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "12-04-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="outer")

# Save to CSV
#df.to_csv('12-04-2023_c2_test3.csv', index=False)
group_1_df = df[(df['Test ID'] == 620) & (df['Person ID'] == 156)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('12-04-2023_c2_test3_156_620.csv', index=False)

group_2_df = df[(df['Test ID'] == 620) & (df['Person ID'] == 168)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('12-04-2023_c2_test3_168_620.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test3\Record_2023-04-12_15-26-00.tiff: 480x640 5 persons, 1341.3ms
# Speed: 2.0ms preprocess, 1341.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test3\Record_2023-04-12_15-27-00.tiff: 480x640 2 persons, 1174.1ms
# Speed: 1.0ms preprocess, 1174.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-04-12\camera2\test3\Record_2023-04-12_15