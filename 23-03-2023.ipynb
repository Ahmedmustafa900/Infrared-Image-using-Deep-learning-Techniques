# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\output'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 22 
max_temp = 34.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"23-03-2023",
                        "Person ID": 134,
                        "Test ID": 318,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('23-03-2023_c1_test1.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-24-00.tiff: 480x640 1 person, 3367.6ms
# Speed: 2.0ms preprocess, 3367.6ms inference, 1019.3ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-25-00.tiff: 480x640 2 persons, 2947.9ms
# Speed: 3.0ms preprocess, 2947.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-26-00.tiff: 480x640 2 persons, 2951.6ms
# Speed: 1.0ms preprocess, 2951.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-27-00.tiff: 480x640 3 persons, 2949.4ms
# Speed: 2.0ms preprocess, 2949.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-28-00.tiff: 480x640 2 persons, 2997.1ms
# Speed: 1.0ms preprocess, 2997.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-29-00.tiff: 480x640 3 persons, 2903.7ms
# Speed: 1.0ms preprocess, 2903.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-30-00.tiff: 480x640 3 persons, 2922.1ms
# Speed: 2.0ms preprocess, 2922.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-31-00.tiff: 480x640 3 persons, 2905.7ms
# Speed: 2.0ms preprocess, 2905.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-32-00.tiff: 480x640 3 persons, 2894.7ms
# Speed: 1.0ms preprocess, 2894.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-33-00.tiff: 480x640 2 persons, 2896.7ms
# Speed: 1.0ms preprocess, 2896.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-34-00.tiff: 480x640 2 persons, 2852.7ms
# Speed: 3.0ms preprocess, 2852.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-35-00.tiff: 480x640 2 persons, 2817.7ms
# Speed: 1.0ms preprocess, 2817.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-36-00.tiff: 480x640 4 persons, 2865.7ms
# Speed: 2.0ms preprocess, 2865.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-37-00.tiff: 480x640 3 persons, 2909.6ms
# Speed: 2.0ms preprocess, 2909.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-38-00.tiff: 480x640 3 persons, 2886.9ms
# Speed: 2.0ms preprocess, 2886.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-39-00.tiff: 480x640 3 persons, 2872.9ms
# Speed: 1.0ms preprocess, 2872.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-40-00.tiff: 480x640 3 persons, 2903.7ms
# Speed: 1.0ms preprocess, 2903.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-41-00.tiff: 480x640 3 persons, 2920.0ms
# Speed: 2.0ms preprocess, 2920.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-42-00.tiff: 480x640 3 persons, 2890.6ms
# Speed: 2.0ms preprocess, 2890.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-43-00.tiff: 480x640 3 persons, 2824.1ms
# Speed: 2.0ms preprocess, 2824.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-44-00.tiff: 480x640 3 persons, 2934.2ms
# Speed: 1.0ms preprocess, 2934.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-45-00.tiff: 480x640 2 persons, 2850.0ms
# Speed: 1.0ms preprocess, 2850.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-46-00.tiff: 480x640 3 persons, 2882.7ms
# Speed: 2.0ms preprocess, 2882.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-47-00.tiff: 480x640 2 persons, 2937.9ms
# Speed: 2.0ms preprocess, 2937.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-48-00.tiff: 480x640 2 persons, 2929.7ms
# Speed: 2.0ms preprocess, 2929.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-49-00.tiff: 480x640 3 persons, 2797.7ms
# Speed: 1.0ms preprocess, 2797.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-50-00.tiff: 480x640 2 persons, 2910.1ms
# Speed: 2.0ms preprocess, 2910.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-51-00.tiff: 480x640 2 persons, 3002.6ms
# Speed: 3.0ms preprocess, 3002.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-52-00.tiff: 480x640 3 persons, 2916.7ms
# Speed: 2.0ms preprocess, 2916.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-53-00.tiff: 480x640 2 persons, 2907.2ms
# Speed: 1.0ms preprocess, 2907.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-54-00.tiff: 480x640 2 persons, 2929.9ms
# Speed: 2.0ms preprocess, 2929.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test1\Record_2023-03-23_09-55-00.tiff: 480x640 3 persons, 2960.5ms
# Speed: 1.0ms preprocess, 2960.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.

# %% [markdown]
# Test 2

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\output'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 22 
max_temp = 34.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"23-03-2023",
                        "Person ID": 119,
                        "Test ID": 318,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('23-03-2023_c1_test2.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-25-00.tiff: 480x640 3 persons, 3956.8ms
# Speed: 2.0ms preprocess, 3956.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-26-00.tiff: 480x640 2 persons, 3279.1ms
# Speed: 3.0ms preprocess, 3279.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-27-00.tiff: 480x640 2 persons, 3001.9ms
# Speed: 2.0ms preprocess, 3001.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-28-00.tiff: 480x640 2 persons, 2953.8ms
# Speed: 2.0ms preprocess, 2953.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-29-00.tiff: 480x640 1 person, 2912.9ms
# Speed: 2.0ms preprocess, 2912.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-30-00.tiff: 480x640 2 persons, 2970.8ms
# Speed: 2.0ms preprocess, 2970.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-31-00.tiff: 480x640 2 persons, 2937.9ms
# Speed: 1.0ms preprocess, 2937.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-32-00.tiff: 480x640 2 persons, 2905.8ms
# Speed: 2.0ms preprocess, 2905.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-33-00.tiff: 480x640 2 persons, 2977.8ms
# Speed: 2.0ms preprocess, 2977.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-34-00.tiff: 480x640 2 persons, 2933.4ms
# Speed: 2.0ms preprocess, 2933.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-35-00.tiff: 480x640 2 persons, 2928.8ms
# Speed: 2.0ms preprocess, 2928.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-36-00.tiff: 480x640 3 persons, 2923.7ms
# Speed: 2.0ms preprocess, 2923.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-37-00.tiff: 480x640 2 persons, 2919.7ms
# Speed: 1.0ms preprocess, 2919.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-38-00.tiff: 480x640 1 person, 2910.0ms
# Speed: 2.0ms preprocess, 2910.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-39-00.tiff: 480x640 1 person, 2950.6ms
# Speed: 1.0ms preprocess, 2950.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-40-00.tiff: 480x640 1 person, 2927.0ms
# Speed: 1.0ms preprocess, 2927.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-41-00.tiff: 480x640 2 persons, 2953.5ms
# Speed: 2.0ms preprocess, 2953.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-42-00.tiff: 480x640 1 person, 2950.2ms
# Speed: 2.0ms preprocess, 2950.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-43-00.tiff: 480x640 1 person, 2953.8ms
# Speed: 2.0ms preprocess, 2953.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-44-00.tiff: 480x640 1 person, 2981.9ms
# Speed: 3.0ms preprocess, 2981.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-45-00.tiff: 480x640 2 persons, 2937.7ms
# Speed: 2.0ms preprocess, 2937.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-46-00.tiff: 480x640 1 person, 2861.7ms
# Speed: 2.0ms preprocess, 2861.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-47-00.tiff: 480x640 1 person, 2919.6ms
# Speed: 2.0ms preprocess, 2919.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-48-00.tiff: 480x640 2 persons, 2956.3ms
# Speed: 1.0ms preprocess, 2956.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-49-00.tiff: 480x640 1 person, 2921.5ms
# Speed: 1.0ms preprocess, 2921.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-50-00.tiff: 480x640 2 persons, 2923.9ms
# Speed: 1.0ms preprocess, 2923.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-51-00.tiff: 480x640 1 person, 2963.4ms
# Speed: 1.0ms preprocess, 2963.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-52-00.tiff: 480x640 2 persons, 2863.3ms
# Speed: 2.0ms preprocess, 2863.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-53-00.tiff: 480x640 2 persons, 2890.8ms
# Speed: 2.0ms preprocess, 2890.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-54-00.tiff: 480x640 1 person, 2873.7ms
# Speed: 2.0ms preprocess, 2873.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-55-00.tiff: 480x640 1 person, 2899.2ms
# Speed: 2.0ms preprocess, 2899.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test2\Record_2023-03-23_12-56-00.tiff: 480x640 1 person, 2925.9ms
# Speed: 2.0ms preprocess, 2925.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test3\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 26
max_temp = 33

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"23-03-2023",
                        "Person ID": 131,
                        "Test ID": 300,  #Missing appointment (Marked Yellow in Plannung Csv)
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('23-03-2023_c1_test3_131_300.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test3\Record_2023-03-23_15-15-00.tiff: 480x640 2 persons, 988.2ms
# Speed: 2.0ms preprocess, 988.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera1\test3\Record_2023-03-23_15
# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (420, 190, 580, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 133  
                test_id = 317    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 112  
                test_id = 313    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "23-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('23-03-2023_c2_test1.csv', index=False)
group_1_df = df[(df['Test ID'] == 317) & (df['Person ID'] == 133)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('23-03-2023_c2_test1_133_317.csv', index=False)

group_2_df = df[(df['Test ID'] == 313) & (df['Person ID'] == 112)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('23-03-2023_c2_test1_112_313.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-24-01.tiff: 480x640 3 persons, 962.2ms
# Speed: 0.0ms preprocess, 962.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-25-00_0.tiff: 480x640 2 persons, 936.3ms
# Speed: 1.9ms preprocess, 936.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-26-00_0.tiff: 480x640 2 persons, 1034.8ms
# Speed: 0.0ms preprocess, 1034.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-27-01.tiff: 480x640 3 persons, 945.2ms
# Speed: 0.0ms preprocess, 945.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-28-00_0.tiff: 480x640 3 persons, 895.7ms
# Speed: 0.0ms preprocess, 895.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-29-00_0.tiff: 480x640 2 persons, 810.7ms
# Speed: 8.0ms preprocess, 810.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-30-00_0.tiff: 480x640 2 persons, 808.6ms
# Speed: 0.0ms preprocess, 808.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-31-00_0.tiff: 480x640 2 persons, 821.8ms
# Speed: 0.0ms preprocess, 821.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-32-01.tiff: 480x640 2 persons, 900.0ms
# Speed: 0.0ms preprocess, 900.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-33-00_0.tiff: 480x640 2 persons, 897.9ms
# Speed: 0.0ms preprocess, 897.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-34-01.tiff: 480x640 2 persons, 909.7ms
# Speed: 0.0ms preprocess, 909.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-35-01.tiff: 480x640 2 persons, 968.4ms
# Speed: 0.0ms preprocess, 968.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-36-01.tiff: 480x640 3 persons, 1015.0ms
# Speed: 0.0ms preprocess, 1015.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-37-00_0.tiff: 480x640 2 persons, 912.9ms
# Speed: 8.0ms preprocess, 912.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-38-01.tiff: 480x640 2 persons, 898.5ms
# Speed: 0.0ms preprocess, 898.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-39-01.tiff: 480x640 2 persons, 899.9ms
# Speed: 0.0ms preprocess, 899.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-40-01.tiff: 480x640 2 persons, 875.1ms
# Speed: 0.0ms preprocess, 875.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-41-01.tiff: 480x640 2 persons, 871.6ms
# Speed: 8.0ms preprocess, 871.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-43-01.tiff: 480x640 2 persons, 867.3ms
# Speed: 0.0ms preprocess, 867.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-44-00_0.tiff: 480x640 2 persons, 909.6ms
# Speed: 0.0ms preprocess, 909.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-45-01.tiff: 480x640 2 persons, 909.0ms
# Speed: 0.0ms preprocess, 909.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-46-01.tiff: 480x640 2 persons, 916.7ms
# Speed: 0.0ms preprocess, 916.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-47-01.tiff: 480x640 3 persons, 908.7ms
# Speed: 0.0ms preprocess, 908.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-48-00_0.tiff: 480x640 2 persons, 921.9ms
# Speed: 0.0ms preprocess, 921.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-49-00_0.tiff: 480x640 2 persons, 905.1ms
# Speed: 0.0ms preprocess, 905.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-50-01.tiff: 480x640 4 persons, 920.2ms
# Speed: 0.0ms preprocess, 920.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-51-01.tiff: 480x640 2 persons, 917.4ms
# Speed: 0.0ms preprocess, 917.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-52-01.tiff: 480x640 3 persons, 911.8ms
# Speed: 0.0ms preprocess, 911.8ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-53-00_0.tiff: 480x640 3 persons, 943.9ms
# Speed: 0.0ms preprocess, 943.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-54-01.tiff: 480x640 3 persons, 888.4ms
# Speed: 1.9ms preprocess, 888.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test1\Record_2023-03-23_09-55-00_0.tiff: 480x640 2 persons, 876.0ms
# Speed: 0.0ms preprocess, 876.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.

# %% [markdown]
# test2 camera2

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 21.8 
max_temp = 31

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 131  
                test_id = 317    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 116  
                test_id = 305    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "23-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('23-03-2023_c2_test2.csv', index=False)
group_1_df = df[(df['Test ID'] == 317) & (df['Person ID'] == 131)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('23-03-2023_c2_test2_131_317.csv', index=False)

group_2_df = df[(df['Test ID'] == 305) & (df['Person ID'] == 116)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('23-03-2023_c2_test2_116_305.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-25-00_0.tiff: 480x640 3 persons, 1084.8ms
# Speed: 0.0ms preprocess, 1084.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-26-01.tiff: 480x640 5 persons, 1037.0ms
# Speed: 0.0ms preprocess, 1037.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-27-02.tiff: 480x640 4 persons, 1036.9ms
# Speed: 7.5ms preprocess, 1036.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-28-00_0.tiff: 480x640 4 persons, 957.1ms
# Speed: 1.6ms preprocess, 957.1ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-29-00_0.tiff: 480x640 5 persons, 1011.6ms
# Speed: 0.0ms preprocess, 1011.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-30-01.tiff: 480x640 2 persons, 856.2ms
# Speed: 0.0ms preprocess, 856.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-31-01.tiff: 480x640 4 persons, 855.6ms
# Speed: 0.0ms preprocess, 855.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-32-00_0.tiff: 480x640 6 persons, 853.6ms
# Speed: 0.0ms preprocess, 853.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
# Person 5 is within seat 2 and will be processed.
# Person 6 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-33-01.tiff: 480x640 4 persons, 916.5ms
# Speed: 0.0ms preprocess, 916.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-34-00_0.tiff: 480x640 3 persons, 928.1ms
# Speed: 0.0ms preprocess, 928.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-35-00_0.tiff: 480x640 5 persons, 920.7ms
# Speed: 0.0ms preprocess, 920.7ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-36-00_0.tiff: 480x640 4 persons, 934.9ms
# Speed: 8.0ms preprocess, 934.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-37-00_0.tiff: 480x640 5 persons, 926.7ms
# Speed: 0.0ms preprocess, 926.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-38-01.tiff: 480x640 3 persons, 928.7ms
# Speed: 0.0ms preprocess, 928.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-39-00_0.tiff: 480x640 3 persons, 936.4ms
# Speed: 4.0ms preprocess, 936.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-40-01.tiff: 480x640 3 persons, 935.6ms
# Speed: 0.0ms preprocess, 935.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-41-00_0.tiff: 480x640 4 persons, 926.8ms
# Speed: 0.0ms preprocess, 926.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-42-01.tiff: 480x640 4 persons, 905.0ms
# Speed: 8.0ms preprocess, 905.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-43-00_0.tiff: 480x640 3 persons, 937.9ms
# Speed: 0.0ms preprocess, 937.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-44-01.tiff: 480x640 2 persons, 925.2ms
# Speed: 8.0ms preprocess, 925.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-45-00_0.tiff: 480x640 4 persons, 917.6ms
# Speed: 0.0ms preprocess, 917.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-46-01.tiff: 480x640 3 persons, 935.4ms
# Speed: 0.0ms preprocess, 935.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-47-00_0.tiff: 480x640 2 persons, 924.3ms
# Speed: 0.0ms preprocess, 924.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-48-00_0.tiff: 480x640 4 persons, 927.5ms
# Speed: 0.0ms preprocess, 927.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-49-01.tiff: 480x640 3 persons, 963.9ms
# Speed: 0.0ms preprocess, 963.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-50-01.tiff: 480x640 4 persons, 956.5ms
# Speed: 0.0ms preprocess, 956.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-51-00_0.tiff: 480x640 5 persons, 937.4ms
# Speed: 0.0ms preprocess, 937.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-52-01.tiff: 480x640 3 persons, 919.8ms
# Speed: 1.5ms preprocess, 919.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-53-00_0.tiff: 480x640 2 persons, 956.8ms
# Speed: 2.0ms preprocess, 956.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-54-00_0.tiff: 480x640 5 persons, 926.6ms
# Speed: 0.0ms preprocess, 926.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-55-01.tiff: 480x640 4 persons, 942.2ms
# Speed: 0.0ms preprocess, 942.2ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test2\Record_2023-03-23_12-56-00_0.tiff: 480x640 4 persons, 954.5ms
# Speed: 0.0ms preprocess, 954.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test3\output'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 21.8 
max_temp = 35

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 135  
                test_id = 318    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 125  
                test_id = 309    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "23-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye", "Left_Ear", "Right_Ear"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
df.to_csv('23-03-2023_c2_test3.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test3\Record_2023-03-23_15-16-00_0.tiff: 480x640 2 persons, 2486.2ms
# Speed: 1.0ms preprocess, 2486.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test3\Record_2023-03-23_15-17-00_0.tiff: 480x640 3 persons, 2527.0ms
# Speed: 1.0ms preprocess, 2527.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-23\2023-03-23_camera2\test3\Record_2023-03-23_15