# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 22 
max_temp = 33

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"22-03-2023",
                        "Person ID": 119,
                        "Test ID": 317,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('22-03-2023_c1_test1_119_317.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-15-00_0.tiff: 480x640 2 persons, 1013.6ms
# Speed: 0.0ms preprocess, 1013.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-16-00.tiff: 480x640 3 persons, 926.5ms
# Speed: 2.0ms preprocess, 926.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-17-00_0.tiff: 480x640 2 persons, 967.9ms
# Speed: 0.0ms preprocess, 967.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-18-00_0.tiff: 480x640 5 persons, 919.3ms
# Speed: 0.0ms preprocess, 919.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
# Person 5 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-20-00_0.tiff: 480x640 2 persons, 849.2ms
# Speed: 2.1ms preprocess, 849.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-21-00_0.tiff: 480x640 3 persons, 811.5ms
# Speed: 0.0ms preprocess, 811.5ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-22-00_0.tiff: 480x640 3 persons, 981.1ms
# Speed: 8.0ms preprocess, 981.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-23-00_0.tiff: 480x640 3 persons, 926.0ms
# Speed: 0.0ms preprocess, 926.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-24-00_0.tiff: 480x640 3 persons, 938.5ms
# Speed: 2.0ms preprocess, 938.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-25-00_0.tiff: 480x640 1 person, 939.0ms
# Speed: 0.0ms preprocess, 939.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-26-00.tiff: 480x640 1 person, 925.0ms
# Speed: 0.0ms preprocess, 925.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-27-00.tiff: 480x640 1 person, 938.3ms
# Speed: 0.0ms preprocess, 938.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-28-00_0.tiff: 480x640 1 person, 1048.4ms
# Speed: 0.0ms preprocess, 1048.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-29-00_0.tiff: 480x640 1 person, 991.7ms
# Speed: 0.0ms preprocess, 991.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-30-00_0.tiff: 480x640 1 person, 897.3ms
# Speed: 0.0ms preprocess, 897.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-31-00_0.tiff: 480x640 1 person, 890.3ms
# Speed: 0.0ms preprocess, 890.3ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-33-00_0.tiff: 480x640 2 persons, 867.0ms
# Speed: 0.0ms preprocess, 867.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-34-00.tiff: 480x640 2 persons, 888.1ms
# Speed: 0.0ms preprocess, 888.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-35-00_0.tiff: 480x640 2 persons, 896.7ms
# Speed: 0.0ms preprocess, 896.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-36-00_0.tiff: 480x640 1 person, 902.1ms
# Speed: 2.1ms preprocess, 902.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-37-00.tiff: 480x640 2 persons, 882.5ms
# Speed: 0.0ms preprocess, 882.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-38-00.tiff: 480x640 2 persons, 898.0ms
# Speed: 8.1ms preprocess, 898.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-39-00_0.tiff: 480x640 1 person, 886.6ms
# Speed: 0.0ms preprocess, 886.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-40-01.tiff: 480x640 1 person, 895.4ms
# Speed: 0.0ms preprocess, 895.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-41-00_0.tiff: 480x640 1 person, 889.9ms
# Speed: 0.0ms preprocess, 889.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-42-00_0.tiff: 480x640 1 person, 895.0ms
# Speed: 0.0ms preprocess, 895.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-43-00.tiff: 480x640 1 person, 895.9ms
# Speed: 0.0ms preprocess, 895.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-44-00.tiff: 480x640 1 person, 895.9ms
# Speed: 0.0ms preprocess, 895.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test1\Record_2023-03-22_09-45-00_0.tiff: 480x640 1 person, 886.6ms
# Speed: 0.0ms preprocess, 886.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.

# %% [markdown]
# Test 2 ( 11:30 - 13:00)

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 27 
max_temp = 32.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"22-03-2023",
                        "Person ID": 131,
                        "Test ID": 318,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('22-03-2023_c1_test2_131_318.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-22-00.tiff: 480x640 2 persons, 874.7ms
# Speed: 1.0ms preprocess, 874.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-23-00.tiff: 480x640 2 persons, 875.0ms
# Speed: 17.0ms preprocess, 875.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-24-00.tiff: 480x640 2 persons, 891.9ms
# Speed: 1.0ms preprocess, 891.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-25-00_0.tiff: 480x640 2 persons, 881.2ms
# Speed: 1.0ms preprocess, 881.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-28-00.tiff: 480x640 2 persons, 931.0ms
# Speed: 2.0ms preprocess, 931.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-29-00.tiff: 480x640 2 persons, 892.2ms
# Speed: 1.0ms preprocess, 892.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-31-00.tiff: 480x640 2 persons, 899.2ms
# Speed: 1.0ms preprocess, 899.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-33-00.tiff: 480x640 3 persons, 893.2ms
# Speed: 2.0ms preprocess, 893.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-34-00_0.tiff: 480x640 2 persons, 910.2ms
# Speed: 1.0ms preprocess, 910.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-35-00_0.tiff: 480x640 2 persons, 888.2ms
# Speed: 2.0ms preprocess, 888.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-36-00_0.tiff: 480x640 2 persons, 887.2ms
# Speed: 1.0ms preprocess, 887.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-37-00_0.tiff: 480x640 2 persons, 894.2ms
# Speed: 1.0ms preprocess, 894.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-38-00_0.tiff: 480x640 2 persons, 896.3ms
# Speed: 1.0ms preprocess, 896.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-39-00_0.tiff: 480x640 2 persons, 900.2ms
# Speed: 1.0ms preprocess, 900.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-40-00_0.tiff: 480x640 2 persons, 897.1ms
# Speed: 1.0ms preprocess, 897.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-41-00.tiff: 480x640 2 persons, 899.2ms
# Speed: 1.0ms preprocess, 899.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-42-01_0.tiff: 480x640 2 persons, 898.2ms
# Speed: 1.0ms preprocess, 898.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-43-00_0.tiff: 480x640 2 persons, 897.2ms
# Speed: 2.0ms preprocess, 897.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-44-00.tiff: 480x640 2 persons, 906.2ms
# Speed: 1.0ms preprocess, 906.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-45-00.tiff: 480x640 2 persons, 901.4ms
# Speed: 2.0ms preprocess, 901.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-46-01_0.tiff: 480x640 2 persons, 1098.2ms
# Speed: 1.0ms preprocess, 1098.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-47-00.tiff: 480x640 2 persons, 1156.4ms
# Speed: 2.0ms preprocess, 1156.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-48-00.tiff: 480x640 2 persons, 1070.2ms
# Speed: 2.0ms preprocess, 1070.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-49-00.tiff: 480x640 2 persons, 1184.2ms
# Speed: 2.0ms preprocess, 1184.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-50-00_0.tiff: 480x640 2 persons, 1258.9ms
# Speed: 3.0ms preprocess, 1258.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-51-00.tiff: 480x640 2 persons, 944.4ms
# Speed: 1.0ms preprocess, 944.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test2\Record_2023-03-22_12-52-00.tiff: 480x640 2 persons, 1190.3ms
# Speed: 1.0ms preprocess, 1190.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.

# %% [markdown]
# Test 3 ( 14:30 - 16:00)

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 29 
max_temp = 33

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"22-03-2023",
                        "Person ID": 120,
                        "Test ID": 318,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('22-03-2023_c1_test3_120_318.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-17-00_0.tiff: 480x640 3 persons, 1289.5ms
# Speed: 1.0ms preprocess, 1289.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-18-00_0.tiff: 480x640 2 persons, 1241.4ms
# Speed: 2.0ms preprocess, 1241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-19-00.tiff: 480x640 2 persons, 1408.8ms
# Speed: 1.0ms preprocess, 1408.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-20-00_0.tiff: 480x640 2 persons, 1210.9ms
# Speed: 2.0ms preprocess, 1210.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-21-00_0.tiff: 480x640 2 persons, 1353.4ms
# Speed: 1.0ms preprocess, 1353.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-22-00_0.tiff: 480x640 2 persons, 1339.6ms
# Speed: 2.0ms preprocess, 1339.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-23-00_0.tiff: 480x640 2 persons, 1320.0ms
# Speed: 2.0ms preprocess, 1320.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-24-00_0.tiff: 480x640 2 persons, 1191.5ms
# Speed: 2.0ms preprocess, 1191.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-25-00_0.tiff: 480x640 2 persons, 1165.9ms
# Speed: 1.0ms preprocess, 1165.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-26-00_0.tiff: 480x640 2 persons, 1374.9ms
# Speed: 1.0ms preprocess, 1374.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-27-00_0.tiff: 480x640 2 persons, 1404.5ms
# Speed: 5.0ms preprocess, 1404.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-28-00.tiff: 480x640 2 persons, 1430.9ms
# Speed: 2.0ms preprocess, 1430.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-29-00_0.tiff: 480x640 1 person, 1354.7ms
# Speed: 2.0ms preprocess, 1354.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-30-00_0.tiff: 480x640 2 persons, 1217.5ms
# Speed: 2.0ms preprocess, 1217.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-31-00.tiff: 480x640 2 persons, 1273.6ms
# Speed: 2.0ms preprocess, 1273.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-32-00.tiff: 480x640 2 persons, 1224.9ms
# Speed: 1.0ms preprocess, 1224.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-33-00.tiff: 480x640 2 persons, 1226.1ms
# Speed: 1.0ms preprocess, 1226.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-34-00_0.tiff: 480x640 2 persons, 1160.7ms
# Speed: 1.0ms preprocess, 1160.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-36-01_0.tiff: 480x640 2 persons, 1108.6ms
# Speed: 1.0ms preprocess, 1108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-37-01.tiff: 480x640 2 persons, 1080.0ms
# Speed: 1.0ms preprocess, 1080.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-38-00_0.tiff: 480x640 2 persons, 1086.2ms
# Speed: 1.0ms preprocess, 1086.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-39-00_0.tiff: 480x640 2 persons, 1085.4ms
# Speed: 2.0ms preprocess, 1085.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-40-00.tiff: 480x640 1 person, 1110.7ms
# Speed: 1.0ms preprocess, 1110.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-41-01_0.tiff: 480x640 1 person, 1117.9ms
# Speed: 1.0ms preprocess, 1117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-42-00.tiff: 480x640 2 persons, 1140.7ms
# Speed: 1.0ms preprocess, 1140.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-43-00.tiff: 480x640 2 persons, 1227.6ms
# Speed: 1.0ms preprocess, 1227.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-45-00_0.tiff: 480x640 2 persons, 1599.5ms
# Speed: 2.2ms preprocess, 1599.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-46-00.tiff: 480x640 1 person, 1577.1ms
# Speed: 2.0ms preprocess, 1577.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera1\test3\Record_2023-03-22_15-47-00.tiff: 480x640 3 persons, 1577.6ms
# Speed: 2.0ms preprocess, 1577.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.

# %% [markdown]
# Camera 2 (test 1) (8:30 - 10:00)

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\yolo11'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 24 
max_temp = 33.2

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 128  
                test_id = 318    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 112  
                test_id = 316    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "22-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('22-03-2023_c2_test1.csv', index=False)
group_1_df = df[(df['Test ID'] == 318) & (df['Person ID'] == 128)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('22-03-2023_c2_test1_128_318.csv', index=False)

group_2_df = df[(df['Test ID'] == 316) & (df['Person ID'] == 112)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('22-03-2023_c2_test1_112_316.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-15-00.tiff: 480x640 4 persons, 847.3ms
# Speed: 2.0ms preprocess, 847.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-16-01.tiff: 480x640 5 persons, 802.6ms
# Speed: 2.0ms preprocess, 802.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-17-00.tiff: 480x640 5 persons, 809.7ms
# Speed: 1.0ms preprocess, 809.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
# Person 5 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-18-00.tiff: 480x640 4 persons, 814.0ms
# Speed: 1.0ms preprocess, 814.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-19-00.tiff: 480x640 3 persons, 862.3ms
# Speed: 1.0ms preprocess, 862.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-20-00.tiff: 480x640 3 persons, 872.8ms
# Speed: 1.0ms preprocess, 872.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-21-00.tiff: 480x640 3 persons, 881.4ms
# Speed: 2.0ms preprocess, 881.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-22-00.tiff: 480x640 3 persons, 867.0ms
# Speed: 2.0ms preprocess, 867.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-23-00.tiff: 480x640 3 persons, 911.3ms
# Speed: 1.0ms preprocess, 911.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-24-00.tiff: 480x640 3 persons, 885.4ms
# Speed: 2.0ms preprocess, 885.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-25-00.tiff: 480x640 2 persons, 872.4ms
# Speed: 1.0ms preprocess, 872.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-26-00_0.tiff: 480x640 3 persons, 897.7ms
# Speed: 1.0ms preprocess, 897.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-27-01.tiff: 480x640 2 persons, 871.2ms
# Speed: 1.0ms preprocess, 871.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-28-00.tiff: 480x640 2 persons, 867.3ms
# Speed: 1.0ms preprocess, 867.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-29-00.tiff: 480x640 3 persons, 896.5ms
# Speed: 1.0ms preprocess, 896.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-30-00.tiff: 480x640 2 persons, 888.4ms
# Speed: 1.5ms preprocess, 888.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-31-00.tiff: 480x640 2 persons, 864.7ms
# Speed: 2.0ms preprocess, 864.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-32-00.tiff: 480x640 3 persons, 872.4ms
# Speed: 1.0ms preprocess, 872.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-33-00.tiff: 480x640 3 persons, 870.6ms
# Speed: 2.0ms preprocess, 870.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-34-01.tiff: 480x640 4 persons, 869.7ms
# Speed: 2.0ms preprocess, 869.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-35-00.tiff: 480x640 2 persons, 874.5ms
# Speed: 1.0ms preprocess, 874.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-36-00.tiff: 480x640 2 persons, 871.6ms
# Speed: 2.0ms preprocess, 871.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-37-01.tiff: 480x640 2 persons, 867.3ms
# Speed: 1.0ms preprocess, 867.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-38-01.tiff: 480x640 2 persons, 873.9ms
# Speed: 1.0ms preprocess, 873.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-39-00.tiff: 480x640 2 persons, 884.9ms
# Speed: 2.0ms preprocess, 884.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-40-01_0.tiff: 480x640 2 persons, 874.5ms
# Speed: 1.0ms preprocess, 874.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-41-00.tiff: 480x640 2 persons, 888.8ms
# Speed: 1.0ms preprocess, 888.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-42-00.tiff: 480x640 2 persons, 1356.7ms
# Speed: 1.0ms preprocess, 1356.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-43-01.tiff: 480x640 4 persons, 1077.9ms
# Speed: 1.0ms preprocess, 1077.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test1\Record_2023-03-22_09-45-00.tiff: 480x640 3 persons, 1141.4ms
# Speed: 2.0ms preprocess, 1141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.

# %% [markdown]
# Test 2 Camera 2

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 15
max_temp = 32.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (440, 190, 600, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 120  
                test_id = 317    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 112  
                test_id = 305    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "22-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee","Left_Hip", "Right_Hip"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('22-03-2023_c2_test2.csv', index=False)
group_1_df = df[(df['Test ID'] == 317) & (df['Person ID'] == 120)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('22-03-2023_c2_test2_120_317.csv', index=False)

group_2_df = df[(df['Test ID'] == 305) & (df['Person ID'] == 112)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('22-03-2023_c2_test2_112_305.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-22-01.tiff: 480x640 2 persons, 994.5ms
# Speed: 1.5ms preprocess, 994.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-23-00_0.tiff: 480x640 3 persons, 951.7ms
# Speed: 1.0ms preprocess, 951.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-25-00.tiff: 480x640 2 persons, 958.9ms
# Speed: 1.0ms preprocess, 958.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-26-00.tiff: 480x640 2 persons, 949.3ms
# Speed: 2.0ms preprocess, 949.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-27-00.tiff: 480x640 2 persons, 949.4ms
# Speed: 2.0ms preprocess, 949.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-28-00_0.tiff: 480x640 4 persons, 866.8ms
# Speed: 1.0ms preprocess, 866.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-29-00_0.tiff: 480x640 2 persons, 816.8ms
# Speed: 1.0ms preprocess, 816.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-30-00.tiff: 480x640 2 persons, 804.4ms
# Speed: 1.0ms preprocess, 804.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-32-00.tiff: 480x640 2 persons, 846.8ms
# Speed: 0.0ms preprocess, 846.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-33-02.tiff: 480x640 2 persons, 906.0ms
# Speed: 1.0ms preprocess, 906.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-34-00.tiff: 480x640 2 persons, 906.4ms
# Speed: 1.0ms preprocess, 906.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-35-00.tiff: 480x640 2 persons, 911.8ms
# Speed: 1.0ms preprocess, 911.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-36-00.tiff: 480x640 2 persons, 908.0ms
# Speed: 0.0ms preprocess, 908.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-37-00.tiff: 480x640 2 persons, 907.4ms
# Speed: 1.0ms preprocess, 907.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-38-00.tiff: 480x640 2 persons, 914.0ms
# Speed: 1.0ms preprocess, 914.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-39-00.tiff: 480x640 2 persons, 951.3ms
# Speed: 1.0ms preprocess, 951.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-40-00.tiff: 480x640 2 persons, 910.7ms
# Speed: 1.0ms preprocess, 910.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-41-01.tiff: 480x640 2 persons, 904.4ms
# Speed: 1.0ms preprocess, 904.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-42-01.tiff: 480x640 2 persons, 915.0ms
# Speed: 1.0ms preprocess, 915.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-43-00.tiff: 480x640 2 persons, 920.9ms
# Speed: 1.0ms preprocess, 920.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-44-00_0.tiff: 480x640 2 persons, 922.5ms
# Speed: 2.0ms preprocess, 922.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-45-01.tiff: 480x640 2 persons, 1136.8ms
# Speed: 0.0ms preprocess, 1136.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-46-01.tiff: 480x640 2 persons, 1133.7ms
# Speed: 1.0ms preprocess, 1133.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-47-00_0.tiff: 480x640 2 persons, 1145.3ms
# Speed: 4.1ms preprocess, 1145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-48-00_0.tiff: 480x640 2 persons, 1044.0ms
# Speed: 1.0ms preprocess, 1044.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-49-00_0.tiff: 480x640 2 persons, 1178.6ms
# Speed: 2.0ms preprocess, 1178.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-50-00.tiff: 480x640 2 persons, 1217.8ms
# Speed: 7.0ms preprocess, 1217.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-51-01.tiff: 480x640 2 persons, 1064.2ms
# Speed: 1.0ms preprocess, 1064.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-52-01.tiff: 480x640 2 persons, 942.0ms
# Speed: 1.0ms preprocess, 942.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test2\Record_2023-03-22_12-53-00.tiff: 480x640 3 persons, 979.3ms
# Speed: 2.0ms preprocess, 979.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 25 
max_temp = 34.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 115  
                test_id = 317    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 116  
                test_id = 309    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "22-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('22-03-2023_c2_test3.csv', index=False)
group_1_df = df[(df['Test ID'] == 317) & (df['Person ID'] == 115)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('22-03-2023_c2_test3_115_317.csv', index=False)

group_2_df = df[(df['Test ID'] == 309) & (df['Person ID'] == 116)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('22-03-2023_c2_test3_116_309.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-16-00.tiff: 480x640 3 persons, 970.3ms
# Speed: 2.0ms preprocess, 970.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-17-00.tiff: 480x640 3 persons, 935.3ms
# Speed: 1.0ms preprocess, 935.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-18-00.tiff: 480x640 2 persons, 935.3ms
# Speed: 2.0ms preprocess, 935.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-19-00_0.tiff: 480x640 3 persons, 936.5ms
# Speed: 1.0ms preprocess, 936.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-20-00.tiff: 480x640 3 persons, 962.3ms
# Speed: 1.0ms preprocess, 962.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-21-00.tiff: 480x640 3 persons, 933.3ms
# Speed: 2.0ms preprocess, 933.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-22-00.tiff: 480x640 2 persons, 902.4ms
# Speed: 5.0ms preprocess, 902.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-23-00.tiff: 480x640 2 persons, 805.5ms
# Speed: 1.0ms preprocess, 805.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-24-00.tiff: 480x640 2 persons, 819.8ms
# Speed: 1.0ms preprocess, 819.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-25-00.tiff: 480x640 3 persons, 862.0ms
# Speed: 1.0ms preprocess, 862.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-26-00.tiff: 480x640 3 persons, 897.2ms
# Speed: 1.0ms preprocess, 897.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-27-00.tiff: 480x640 2 persons, 895.8ms
# Speed: 1.0ms preprocess, 895.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-28-01.tiff: 480x640 2 persons, 899.4ms
# Speed: 2.0ms preprocess, 899.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-29-00.tiff: 480x640 3 persons, 901.3ms
# Speed: 1.0ms preprocess, 901.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-30-00.tiff: 480x640 3 persons, 897.2ms
# Speed: 1.0ms preprocess, 897.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-31-01.tiff: 480x640 2 persons, 896.7ms
# Speed: 1.0ms preprocess, 896.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-32-01.tiff: 480x640 3 persons, 904.7ms
# Speed: 1.0ms preprocess, 904.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-33-01.tiff: 480x640 4 persons, 901.3ms
# Speed: 1.0ms preprocess, 901.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-34-00.tiff: 480x640 2 persons, 900.9ms
# Speed: 1.0ms preprocess, 900.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-35-00.tiff: 480x640 3 persons, 898.1ms
# Speed: 2.0ms preprocess, 898.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-36-01.tiff: 480x640 2 persons, 895.4ms
# Speed: 2.0ms preprocess, 895.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-37-00.tiff: 480x640 2 persons, 987.8ms
# Speed: 2.0ms preprocess, 987.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-38-00.tiff: 480x640 2 persons, 908.6ms
# Speed: 1.0ms preprocess, 908.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-39-00.tiff: 480x640 2 persons, 901.4ms
# Speed: 2.0ms preprocess, 901.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-40-01.tiff: 480x640 4 persons, 905.3ms
# Speed: 1.0ms preprocess, 905.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-41-01.tiff: 480x640 3 persons, 898.6ms
# Speed: 1.0ms preprocess, 898.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-43-00_0.tiff: 480x640 2 persons, 912.4ms
# Speed: 2.0ms preprocess, 912.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-44-00.tiff: 480x640 2 persons, 898.7ms
# Speed: 1.0ms preprocess, 898.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-45-00.tiff: 480x640 3 persons, 910.8ms
# Speed: 1.0ms preprocess, 910.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-22\2023-03-22_Camera2\test3\Record_2023-03-22_15-46-00_0.tiff: 480x640 2 persons, 903.3ms
# Speed: 1.0ms preprocess, 903.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
