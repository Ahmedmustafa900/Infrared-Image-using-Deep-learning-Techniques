# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\output'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 13.1 
max_temp = 36.8

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"20-03-2023",
                        "Person ID": 117,
                        "Test ID": 300,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('20-03-2023_c1_test2.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-20-00.tiff: 480x640 2 persons, 3090.9ms
# Speed: 4.0ms preprocess, 3090.9ms inference, 1400.4ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-21-00.tiff: 480x640 3 persons, 2977.1ms
# Speed: 3.0ms preprocess, 2977.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-22-01.tiff: 480x640 3 persons, 2881.2ms
# Speed: 2.0ms preprocess, 2881.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-23-00.tiff: 480x640 3 persons, 2851.8ms
# Speed: 2.0ms preprocess, 2851.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-24-00.tiff: 480x640 4 persons, 2851.2ms
# Speed: 2.0ms preprocess, 2851.2ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-25-00.tiff: 480x640 2 persons, 2909.7ms
# Speed: 1.0ms preprocess, 2909.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-26-00.tiff: 480x640 2 persons, 2963.0ms
# Speed: 2.0ms preprocess, 2963.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-27-00.tiff: 480x640 3 persons, 3014.8ms
# Speed: 1.0ms preprocess, 3014.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-28-00.tiff: 480x640 3 persons, 2989.1ms
# Speed: 2.0ms preprocess, 2989.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-29-00.tiff: 480x640 2 persons, 3028.1ms
# Speed: 2.0ms preprocess, 3028.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-30-00.tiff: 480x640 3 persons, 2998.9ms
# Speed: 2.0ms preprocess, 2998.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-31-00.tiff: 480x640 2 persons, 2977.8ms
# Speed: 2.0ms preprocess, 2977.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-32-00.tiff: 480x640 2 persons, 2992.7ms
# Speed: 1.0ms preprocess, 2992.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-33-00.tiff: 480x640 2 persons, 2934.4ms
# Speed: 2.0ms preprocess, 2934.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-34-00.tiff: 480x640 2 persons, 2999.5ms
# Speed: 1.0ms preprocess, 2999.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-35-00.tiff: 480x640 2 persons, 2966.7ms
# Speed: 2.0ms preprocess, 2966.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-36-00.tiff: 480x640 2 persons, 2953.3ms
# Speed: 1.0ms preprocess, 2953.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-37-00.tiff: 480x640 2 persons, 2948.4ms
# Speed: 1.0ms preprocess, 2948.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-38-00.tiff: 480x640 2 persons, 2948.9ms
# Speed: 2.0ms preprocess, 2948.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-39-00.tiff: 480x640 3 persons, 2920.9ms
# Speed: 2.0ms preprocess, 2920.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-40-00.tiff: 480x640 4 persons, 2969.4ms
# Speed: 1.0ms preprocess, 2969.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-41-00.tiff: 480x640 2 persons, 2923.3ms
# Speed: 2.0ms preprocess, 2923.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-42-00.tiff: 480x640 4 persons, 2973.3ms
# Speed: 1.0ms preprocess, 2973.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-43-00.tiff: 480x640 2 persons, 2948.1ms
# Speed: 1.0ms preprocess, 2948.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-44-00.tiff: 480x640 2 persons, 2851.1ms
# Speed: 2.0ms preprocess, 2851.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-45-00.tiff: 480x640 2 persons, 2915.0ms
# Speed: 3.0ms preprocess, 2915.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-46-00.tiff: 480x640 2 persons, 2924.4ms
# Speed: 2.0ms preprocess, 2924.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-47-00.tiff: 480x640 3 persons, 2893.9ms
# Speed: 2.0ms preprocess, 2893.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-48-00.tiff: 480x640 2 persons, 2853.7ms
# Speed: 1.0ms preprocess, 2853.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-49-00.tiff: 480x640 3 persons, 2887.8ms
# Speed: 1.0ms preprocess, 2887.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test2\Record_2023-03-20_12-50-00.tiff: 480x640 2 persons, 2909.7ms
# Speed: 2.0ms preprocess, 2909.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.

# %% [markdown]
# Test 3 (Test 1 is Missing)

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 20 
max_temp = 39

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the region of interest (ROI)
roi_top_left = (250, 90)  # (x, y)
roi_bottom_right = (450, 600)  # (x, y)

# Initialize an empty list to store results
results_list = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi_top_left, roi_bottom_right):
    x, y = kpt
    return (roi_top_left[0] <= x <= roi_bottom_right[0]) and (roi_top_left[1] <= y <= roi_bottom_right[1])

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROI rectangle on the color image
        cv2.rectangle(color_image, roi_top_left, roi_bottom_right, (255, 0, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):

            # Check if more than 50% of the keypoints are within the ROI
            keypoints_within_roi = np.sum(
                [within_roi(kpt, roi_top_left, roi_bottom_right) for kpt in person_keypoints]
            )
            
            if keypoints_within_roi <= len(person_keypoints) * 0.5:
                print(f"Person {person_idx + 1} is outside the ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within the ROI and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"20-03-2023",
                        "Person ID": 124,
                        "Test ID": 300,
                        "Seat ID": 5,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist", "Left_Elbow", "Right_Elbow"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Person"], how="left")

# Save to CSV
df.to_csv('20-03-2023_c1_test3.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-23-00.tiff: 480x640 4 persons, 998.2ms
# Speed: 2.0ms preprocess, 998.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-24-00.tiff: 480x640 4 persons, 954.2ms
# Speed: 1.0ms preprocess, 954.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-25-00.tiff: 480x640 4 persons, 892.6ms
# Speed: 1.0ms preprocess, 892.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-26-00.tiff: 480x640 3 persons, 804.8ms
# Speed: 1.5ms preprocess, 804.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-27-00.tiff: 480x640 3 persons, 807.1ms
# Speed: 2.0ms preprocess, 807.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-28-00.tiff: 480x640 4 persons, 760.2ms
# Speed: 1.0ms preprocess, 760.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-29-00.tiff: 480x640 4 persons, 794.2ms
# Speed: 1.0ms preprocess, 794.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-30-00.tiff: 480x640 5 persons, 861.2ms
# Speed: 1.0ms preprocess, 861.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is outside the ROI and will be ignored.
# Person 2 is within the ROI and will be processed.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
# Person 5 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-31-00.tiff: 480x640 2 persons, 852.2ms
# Speed: 1.0ms preprocess, 852.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-32-00.tiff: 480x640 4 persons, 859.7ms
# Speed: 1.0ms preprocess, 859.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
# Person 4 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-33-00.tiff: 480x640 2 persons, 855.2ms
# Speed: 1.0ms preprocess, 855.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-34-00.tiff: 480x640 2 persons, 850.2ms
# Speed: 1.0ms preprocess, 850.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-35-00.tiff: 480x640 2 persons, 859.2ms
# Speed: 1.0ms preprocess, 859.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-36-00.tiff: 480x640 3 persons, 856.2ms
# Speed: 1.0ms preprocess, 856.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-37-00.tiff: 480x640 3 persons, 850.2ms
# Speed: 1.0ms preprocess, 850.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-38-00.tiff: 480x640 2 persons, 862.2ms
# Speed: 1.0ms preprocess, 862.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-39-00.tiff: 480x640 2 persons, 860.7ms
# Speed: 1.0ms preprocess, 860.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-40-00.tiff: 480x640 2 persons, 854.2ms
# Speed: 1.0ms preprocess, 854.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-41-00.tiff: 480x640 3 persons, 854.2ms
# Speed: 1.0ms preprocess, 854.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-42-00.tiff: 480x640 3 persons, 860.2ms
# Speed: 2.0ms preprocess, 860.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-43-00.tiff: 480x640 3 persons, 854.2ms
# Speed: 1.0ms preprocess, 854.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-44-00.tiff: 480x640 2 persons, 873.2ms
# Speed: 1.0ms preprocess, 873.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-45-00.tiff: 480x640 3 persons, 863.2ms
# Speed: 1.0ms preprocess, 863.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-46-00.tiff: 480x640 3 persons, 859.2ms
# Speed: 2.0ms preprocess, 859.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-47-00.tiff: 480x640 3 persons, 878.2ms
# Speed: 2.0ms preprocess, 878.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-48-00.tiff: 480x640 3 persons, 868.2ms
# Speed: 2.0ms preprocess, 868.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-49-00.tiff: 480x640 3 persons, 891.2ms
# Speed: 1.0ms preprocess, 891.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-50-00.tiff: 480x640 2 persons, 865.2ms
# Speed: 1.0ms preprocess, 865.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-51-00.tiff: 480x640 3 persons, 857.2ms
# Speed: 1.0ms preprocess, 857.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-52-00.tiff: 480x640 3 persons, 863.2ms
# Speed: 1.0ms preprocess, 863.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-53-00.tiff: 480x640 3 persons, 854.2ms
# Speed: 1.0ms preprocess, 854.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera1\test3\Record_2023-03-20_15-54-00.tiff: 480x640 3 persons, 861.2ms
# Speed: 1.0ms preprocess, 861.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within the ROI and will be processed.
# Person 2 is outside the ROI and will be ignored.
# Person 3 is outside the ROI and will be ignored.

# %% [markdown]
# Camera 2 (Test 2)

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\output1'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 20
max_temp = 35

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )
            
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 119
                left_seat_persons.append((person_idx, person_keypoints))
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 116
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date":"20-03-2023",
                        "Person ID": person_id,
                        "Test ID": 300,
                        "Seat ID": seat_id,
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow","Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('20-03-2023_c2_test2.csv', index=False)
group_1_df = df[(df['Test ID'] == 300) & (df['Person ID'] == 119)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('20-03-2023_c2_test2_119_300.csv', index=False)

group_2_df = df[(df['Test ID'] == 300) & (df['Person ID'] == 116)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('20-03-2023_c2_test2_116_300.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-20-11.tiff: 480x640 4 persons, 3962.0ms
# Speed: 8.0ms preprocess, 3962.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-21-11.tiff: 480x640 2 persons, 2910.5ms
# Speed: 0.0ms preprocess, 2910.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-22-11.tiff: 480x640 2 persons, 2853.4ms
# Speed: 0.0ms preprocess, 2853.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-23-11.tiff: 480x640 2 persons, 2859.7ms
# Speed: 0.0ms preprocess, 2859.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-24-11.tiff: 480x640 4 persons, 2831.1ms
# Speed: 0.0ms preprocess, 2831.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-25-11.tiff: 480x640 2 persons, 2855.7ms
# Speed: 8.0ms preprocess, 2855.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-26-11.tiff: 480x640 3 persons, 2866.6ms
# Speed: 0.0ms preprocess, 2866.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-27-11.tiff: 480x640 2 persons, 2876.8ms
# Speed: 8.0ms preprocess, 2876.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-28-11.tiff: 480x640 2 persons, 2851.5ms
# Speed: 0.0ms preprocess, 2851.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-29-11.tiff: 480x640 3 persons, 2841.6ms
# Speed: 8.0ms preprocess, 2841.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-30-11.tiff: 480x640 2 persons, 2887.3ms
# Speed: 0.0ms preprocess, 2887.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-31-11.tiff: 480x640 4 persons, 2867.3ms
# Speed: 0.0ms preprocess, 2867.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-32-11.tiff: 480x640 4 persons, 2900.4ms
# Speed: 0.0ms preprocess, 2900.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-33-11.tiff: 480x640 2 persons, 2846.0ms
# Speed: 8.0ms preprocess, 2846.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-34-11.tiff: 480x640 2 persons, 2855.5ms
# Speed: 0.0ms preprocess, 2855.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-35-11.tiff: 480x640 5 persons, 2853.9ms
# Speed: 0.0ms preprocess, 2853.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-36-11.tiff: 480x640 2 persons, 2844.6ms
# Speed: 0.0ms preprocess, 2844.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-37-11.tiff: 480x640 2 persons, 2845.2ms
# Speed: 0.0ms preprocess, 2845.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-38-11.tiff: 480x640 3 persons, 2833.6ms
# Speed: 0.0ms preprocess, 2833.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-39-11.tiff: 480x640 3 persons, 2847.2ms
# Speed: 0.0ms preprocess, 2847.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-40-11.tiff: 480x640 3 persons, 2817.2ms
# Speed: 8.0ms preprocess, 2817.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-41-11.tiff: 480x640 3 persons, 2932.0ms
# Speed: 0.0ms preprocess, 2932.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-42-11.tiff: 480x640 4 persons, 2842.3ms
# Speed: 0.0ms preprocess, 2842.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-43-11.tiff: 480x640 2 persons, 2841.6ms
# Speed: 0.0ms preprocess, 2841.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-44-11.tiff: 480x640 3 persons, 2875.4ms
# Speed: 0.0ms preprocess, 2875.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-45-11.tiff: 480x640 4 persons, 2854.7ms
# Speed: 0.0ms preprocess, 2854.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-46-11.tiff: 480x640 4 persons, 2853.7ms
# Speed: 0.0ms preprocess, 2853.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-47-11.tiff: 480x640 3 persons, 2831.5ms
# Speed: 8.0ms preprocess, 2831.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-48-11.tiff: 480x640 3 persons, 2867.7ms
# Speed: 0.0ms preprocess, 2867.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-49-11.tiff: 480x640 3 persons, 2846.0ms
# Speed: 0.0ms preprocess, 2846.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test2\Record_2023-03-20_12-50-11.tiff: 480x640 2 persons, 2838.9ms
# Speed: 0.0ms preprocess, 2838.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.

# %% [markdown]
# Test 3

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np
import pandas as pd

model = YOLO('yolov8x-pose.pt')
# Directory containing images
image_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3'
# Directory to save annotated images
output_directory = r'C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\yolo8'

# Create output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Calibration parameters taken from the Pixconnect Software
min_temp = 24.8 
max_temp = 32.5

# Create LUT for 8-bit pixel values
lut = np.linspace(min_temp, max_temp, 256)

# Custom labels for keypoints
custom_labels = {
    0: "Nose", 
    1: "Left_Eye", 
    2: "Right_Eye", 
    3: "Left_Ear", 
    4: "Right_Ear", 
    5: "Left_Shoulder", 
    6: "Right_Shoulder", 
    7: "Left_Elbow", 
    8: "Right_Elbow", 
    9: "Left_Wrist", 
    10: "Right_Wrist", 
    11: "Left_Hip", 
    12: "Right_Hip", 
    13: "Left_Knee", 
    14: "Right_Knee", 
    15: "Left_Ankle", 
    16: "Right_Ankle"
}

# Define the regions of interest (ROIs) for two seats
roi_seat_4 = (50, 190, 200, 600)  # (x1, y1, x2, y2) for seat 4
roi_seat_2 = (400, 190, 560, 600)  # (x1, y1, x2, y2) for seat 2

# Initialize lists to store results
results_list = []
left_seat_persons = []
right_seat_persons = []

# Function to check if the keypoints are within the ROI
def within_roi(kpt, roi):
    x, y = kpt
    x1, y1, x2, y2 = roi
    return (x1 <= x <= x2) and (y1 <= y <= y2)

# Function to extract the time part from the filename in HH-MM-SS format
def extract_time_from_filename(filename):
    base_name = os.path.splitext(filename)[0]  # Remove file extension
    parts = base_name.split('_')
    
    # Handle format with date and time: Record_2023-03-30_HH-MM-SS or Record_2023-03-30_HH-MM-SS_suffix
    if len(parts) >= 3 and parts[0] == 'Record':
        time_part = parts[2]
        if len(time_part) == 8 and time_part.count('-') == 2:
            return time_part.replace('-', ':')
    
    return None

# Process each image in the directory
for image_filename in os.listdir(image_directory):
    if image_filename.endswith('.tiff'):
        image_path = os.path.join(image_directory, image_filename)
        
        # Load the image
        thermal_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read as 8-bit grayscale
        color_image = cv2.imread(image_path)

        # Check if the image is loaded properly
        if thermal_image is None or color_image is None:
            print(f"The image file {image_path} could not be loaded. Skipping.")
            continue

        # Apply LUT to convert pixel values to temperature values
        temperature_image = lut[thermal_image]

        # Run YOLO model on the image
        results = model(image_path)

        # Access keypoints for all detected persons
        keypoints = results[0].keypoints

        # Convert keypoints to numpy for easier manipulation
        keypoints_xy = keypoints.xy.numpy()

        # Draw the ROIs on the color image
        cv2.rectangle(color_image, (roi_seat_4[0], roi_seat_4[1]), (roi_seat_4[2], roi_seat_4[3]), (255, 0, 0), 2)
        cv2.rectangle(color_image, (roi_seat_2[0], roi_seat_2[1]), (roi_seat_2[2], roi_seat_2[3]), (0, 255, 0), 2)

        # Extract time from filename
        time_extracted = extract_time_from_filename(image_filename)

        # If time extraction fails, print a warning and skip the image
        if not time_extracted:
            print(f"Warning: Could not extract time from filename {image_filename}. Skipping.")
            continue

        # Iterate over each detected person's keypoints
        for person_idx, person_keypoints in enumerate(keypoints_xy):
            # Check if the keypoints are within either ROI
            keypoints_within_seat_4 = np.sum(
                [within_roi(kpt, roi_seat_4) for kpt in person_keypoints]
            )
            keypoints_within_seat_2 = np.sum(
                [within_roi(kpt, roi_seat_2) for kpt in person_keypoints]
            )

            # If the person is predominantly in seat 4
            if keypoints_within_seat_4 > len(person_keypoints) * 0.5:
                seat_id = 4
                seat_label = "4"
                person_id = 123  
                test_id = 300    
                left_seat_persons.append((person_idx, person_keypoints))
            # If the person is predominantly in seat 2
            elif keypoints_within_seat_2 > len(person_keypoints) * 0.5:
                seat_id = 2
                seat_label = "2"
                person_id = 126  
                test_id = 300    
                right_seat_persons.append((person_idx, person_keypoints))
            else:
                print(f"Person {person_idx + 1} is not predominantly in either ROI and will be ignored.")
                continue

            print(f"Person {person_idx + 1} is within seat {seat_label} and will be processed.")
            # Process keypoints for the person
            for i in range(17):
                kpt = person_keypoints[i]
                x, y = int(kpt[0]), int(kpt[1])

                # Ensure the keypoint coordinates are within the image bounds
                if 0 <= x < temperature_image.shape[1] and 0 <= y < temperature_image.shape[0]:
                    # Get the temperature at the keypoint
                    temperature_at_point = temperature_image[y, x]
                    results_list.append({ 
                        "Image": image_filename,
                        "Time": time_extracted,
                        "Date": "20-03-2023",
                        "Person ID": person_id,  
                        "Test ID": test_id,       
                        "Seat ID": seat_id,    
                        "Person": person_idx + 1,
                        "Keypoint": custom_labels[i],
                        "Temperature (°C)": temperature_at_point
                    })

                    # Annotate the color image with the keypoint and temperature
                    cv2.circle(color_image, (x, y), radius=3, color=(0, 255, 0), thickness=-1)
                    label = f"{temperature_at_point:.1f}C"
                    cv2.putText(color_image, label, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Save the annotated image in the output directory
        annotated_image_path = os.path.join(output_directory, f"annotated_{image_filename}")
        cv2.imwrite(annotated_image_path, color_image)

# Create DataFrame and save to CSV
df = pd.DataFrame(results_list)

# Create lists of keypoints for HeadAll, HandAll, ShinAll, BackAll, and ArmsAll
head_all_keypoints = ["Nose", "Left_Eye", "Right_Eye"]
hand_all_keypoints = ["Left_Wrist", "Right_Wrist"]
shin_all_keypoints = ["Left_Knee", "Right_Knee", "Left_Ankle", "Right_Ankle"]
back_all_keypoints = ["Left_Hip", "Right_Hip"]
arms_all_keypoints = ["Left_Elbow", "Right_Elbow", "Left_Shoulder", "Right_Shoulder"]

# Calculate HeadAll temperatures
head_df = df[df["Keypoint"].isin(head_all_keypoints)]
headall_df = head_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HeadAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate HandAll temperatures
hand_df = df[df["Keypoint"].isin(hand_all_keypoints)]
handall_df = hand_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    HandAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ShinAll temperatures
shin_df = df[df["Keypoint"].isin(shin_all_keypoints)]
shinall_df = shin_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ShinAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate BackAll temperatures
back_df = df[df["Keypoint"].isin(back_all_keypoints)]
backall_df = back_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    BackAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Calculate ArmsAll temperatures
arms_df = df[df["Keypoint"].isin(arms_all_keypoints)]
armsall_df = arms_df.groupby(["Image", "Time", "Date", "Seat ID", "Person"]).agg(
    ArmsAll_Temperature=("Temperature (°C)", "mean")
).reset_index()

# Merge the HeadAll, HandAll, ShinAll, BackAll, and ArmsAll temperatures back to the original DataFrame
df = pd.merge(df, headall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, handall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, shinall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, backall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")
df = pd.merge(df, armsall_df, on=["Image", "Time", "Date", "Seat ID", "Person"], how="left")

# Save to CSV
#df.to_csv('20-03-2023_c2_test3.csv', index=False)
group_1_df = df[(df['Test ID'] == 300) & (df['Person ID'] == 123)]
df1 = pd.merge(group_1_df, df)

# Save the filtered data to a CSV for the first group
df1.to_csv('20-03-2023_c2_test3_123_300.csv', index=False)

group_2_df = df[(df['Test ID'] == 300) & (df['Person ID'] == 126)]
df2 = pd.merge(group_2_df, df)
# Save the filtered data to a CSV for the second group
df2.to_csv('20-03-2023_c2_test3_126_300.csv', index=False)
# Out:
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-24-10.tiff: 480x640 2 persons, 1183.2ms
# Speed: 2.0ms preprocess, 1183.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-25-10.tiff: 480x640 2 persons, 1208.6ms
# Speed: 1.0ms preprocess, 1208.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-26-10.tiff: 480x640 2 persons, 1131.8ms
# Speed: 2.0ms preprocess, 1131.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-27-10.tiff: 480x640 4 persons, 1052.2ms
# Speed: 1.0ms preprocess, 1052.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-28-11.tiff: 480x640 3 persons, 1052.6ms
# Speed: 1.0ms preprocess, 1052.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is not predominantly in either ROI and will be ignored.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-29-11.tiff: 480x640 4 persons, 1046.5ms
# Speed: 2.0ms preprocess, 1046.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-30-11.tiff: 480x640 4 persons, 1041.4ms
# Speed: 1.0ms preprocess, 1041.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-31-11.tiff: 480x640 5 persons, 1046.3ms
# Speed: 2.0ms preprocess, 1046.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
# Person 4 is within seat 2 and will be processed.
# Person 5 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-32-11.tiff: 480x640 3 persons, 1034.9ms
# Speed: 1.0ms preprocess, 1034.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-33-11.tiff: 480x640 4 persons, 1082.1ms
# Speed: 1.0ms preprocess, 1082.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is not predominantly in either ROI and will be ignored.
# Person 4 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-34-11.tiff: 480x640 3 persons, 1046.3ms
# Speed: 2.0ms preprocess, 1046.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-35-11.tiff: 480x640 3 persons, 1037.7ms
# Speed: 2.0ms preprocess, 1037.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-36-11.tiff: 480x640 2 persons, 1045.0ms
# Speed: 1.0ms preprocess, 1045.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-37-11.tiff: 480x640 2 persons, 1095.7ms
# Speed: 1.0ms preprocess, 1095.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-38-11.tiff: 480x640 2 persons, 1108.0ms
# Speed: 1.0ms preprocess, 1108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-39-11.tiff: 480x640 2 persons, 1056.4ms
# Speed: 2.0ms preprocess, 1056.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-40-11.tiff: 480x640 2 persons, 1083.9ms
# Speed: 2.0ms preprocess, 1083.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-41-11.tiff: 480x640 3 persons, 1041.0ms
# Speed: 2.0ms preprocess, 1041.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
# Person 3 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-42-11.tiff: 480x640 2 persons, 1033.7ms
# Speed: 1.0ms preprocess, 1033.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-43-11.tiff: 480x640 2 persons, 1047.1ms
# Speed: 1.0ms preprocess, 1047.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-44-11.tiff: 480x640 2 persons, 1040.7ms
# Speed: 1.0ms preprocess, 1040.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-45-11.tiff: 480x640 2 persons, 1035.6ms
# Speed: 1.0ms preprocess, 1035.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-46-11.tiff: 480x640 2 persons, 1055.1ms
# Speed: 1.0ms preprocess, 1055.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-47-11.tiff: 480x640 2 persons, 1048.6ms
# Speed: 1.0ms preprocess, 1048.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-48-10.tiff: 480x640 2 persons, 1045.1ms
# Speed: 1.0ms preprocess, 1045.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-49-10.tiff: 480x640 2 persons, 1030.4ms
# Speed: 1.0ms preprocess, 1030.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-50-10.tiff: 480x640 2 persons, 1030.4ms
# Speed: 2.0ms preprocess, 1030.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-51-10.tiff: 480x640 2 persons, 1074.1ms
# Speed: 1.0ms preprocess, 1074.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-52-10.tiff: 480x640 2 persons, 1018.6ms
# Speed: 2.0ms preprocess, 1018.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 4 and will be processed.
# Person 2 is within seat 2 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-53-10.tiff: 480x640 2 persons, 1029.7ms
# Speed: 1.0ms preprocess, 1029.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is within seat 4 and will be processed.
#
# image 1/1 C:\Users\AMUS\python\Dataset\2023-03-20\camera2\test3\Record_2023-03-20_15-54-10.tiff: 480x640 4 persons, 1042.3ms
# Speed: 2.0ms preprocess, 1042.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Person 1 is within seat 2 and will be processed.
# Person 2 is not predominantly in either ROI and will be ignored.
# Person 3 is within seat 4 and will be processed.
# Person 4 is not predominantly in either ROI and will be ignored.
